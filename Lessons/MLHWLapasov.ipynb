# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img2 = plt.imread(r"C:\Users\user\Desktop\Datas\images (3).jfif")
img2.shape
# Out:
# (163, 307, 3)

# %%
print(plt.imshow(img))
# Out:
# AxesImage(shape=(163, 307, 3))

# %%
print(plt.imshow(np.fliplr(img)))
# Out:
# AxesImage(shape=(163, 307, 3))

# %%
print(plt.imshow(np.flipud(img)))
# Out:
# AxesImage(shape=(163, 307, 3))

# %%
print(plt.imshow(np.rot90(img, k=2)))
# Out:
# AxesImage(shape=(163, 307, 3))

# %%
print(plt.imshow(np.flipud(img+40)))
# Out:
# AxesImage(shape=(163, 307, 3))

# %%
def augment(img):
    buyruq=input("buyruqni kiriting: (misol uchun: asl rasm,\n gorizontal agdarilgan,\n 180 burilgan,\n yorqinlashtirilgan (+40, clip bilan))")
    if buyruq.lower()=='asl rasm':
        return plt.imshow(img)
    elif buyruq.lower()=='gorizontal agdarilgan':
        return plt.imshow(np.fliplr(img))
    elif buyruq.lower()=='180 burilgan':
        return plt.imshow(np.rot90(img, k=2))
    elif buyruq.lower()=='yorqinlashtirilgan (+40, clip bilan)':
        return plt.imshow(img+40)
print(augment(img2))
# Out:
# AxesImage(shape=(163, 307, 3))

# %%
Fig, axes=plt.subplots(1, 5, figsize=(14, 3.5))
axes[0].imshow(img2)
axes[1].imshow(np.fliplr(img2))
axes[2].imshow(np.flipud(img2))
axes[3].imshow(img2+40)
axes[4].imshow(np.rot90(img2, k=1))

# %%
img3=plt.imread(r"C:\Users\user\Desktop\photo_2026-02-26_17-51-04.jpg")
Fig, axes=plt.subplots(1, 5, figsize=(14, 3.5))
axes[0].imshow(img3)
axes[1].imshow(np.fliplr(img3))
axes[2].imshow(np.flipud(img3))
axes[3].imshow(img3+40)
axes[4].imshow(np.rot90(img3, k=1))
axes[4].imshow(np.rot90(img3, k=2))
